# %%
import pandas as pd

df = pd.read_excel('Planilhas/FORMULÁRIO GERAL DE RESULTADOS DAS CAMPANHAS DO LIMPA BRASIL (respostas) (5).xlsx')
df
# Out:
#            Carimbo de data/hora                            Nome  \
# 0    2021-03-09 14:26:44.684000     FRANCISCO DOS SANTOS BORGES
# 1    2021-03-09 22:11:13.925000  juliana de Souza Pinto Machado
# 2    2021-03-10 15:11:02.905000                 Vanessa da Cruz
# 3    2021-03-11 15:27:03.435000          Elen Borges dos Santos
# 4    2021-03-14 10:00:54.685000   75 Grupo Escoteiro Sao Thiago
# ..                          ...                             ...
# 185  2024-06-12 07:38:58.977000                          Diego
# 186  2024-06-12 11:58:59.754000                   Edmi Moreira
# 187  2024-06-12 15:16:28.950000       Amanda Aymê Santos Bueno
# 188  2024-06-21 15:42:43.833000                             NaN
# 189  2024-10-07 12:22:09.438000                   Edmi Moreira
#
#                             E-mail Telefone/Celular  \
# 0             chicokaa@hotmail.com   +5598991850053
# 1     julianadespmachado@gmail.com   +5554996715858
# ...

# %%
sem_nan = df.dropna(subset=['Nome do local:'])
duplicatas = sem_nan[sem_nan.duplicated(subset='Nome do local:')][sem_nan['Você realizou um mutirão de limpeza?'] == 'Sim']
duplicatas[['Nome do local:', 'Data']]
# Out:
# C:\Users\54094462830\AppData\Local\Temp\ipykernel_17520\462497355.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   duplicatas = sem_nan[sem_nan.duplicated(subset='Nome do local:')][sem_nan['Você realizou um mutirão de limpeza?'] == 'Sim']
#         Nome do local:                 Data
# 132     Cais do porto   2022-06-05 00:00:00
# 133           Bequimão  2022-06-05 00:00:00
# 157    Praia do Reduto  2023-06-04 00:00:00
# 174      Praia do Leme  2024-02-24 00:00:00
# 181              Praia  2024-06-08 00:00:00
# 184                Rua  2024-06-09 00:00:00
# 185  Praia de iracema   2024-06-08 00:00:00
